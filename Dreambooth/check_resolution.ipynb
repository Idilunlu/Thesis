# %%
from PIL import Image
import os

def list_image_resolutions(directory):
    # List all files in the directory
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        try:
            with Image.open(filepath) as img:
                print(f"{filename}: {img.size} (width x height)")
        except IOError:
            print(f"Failed to open {filename}")

# Specify the directory containing your images
image_directory = '/home/idu675/projects/Thesis/catDreambooth/outputs_filtered'
list_image_resolutions(image_directory)
# Out:
# epoch_100_image_0.png: (512, 512) (width x height)
# epoch_100_image_1.png: (512, 512) (width x height)
# epoch_100_image_2.png: (512, 512) (width x height)
# epoch_100_image_3.png: (512, 512) (width x height)
# epoch_104_image_0.png: (512, 512) (width x height)
# epoch_104_image_1.png: (512, 512) (width x height)
# epoch_104_image_2.png: (512, 512) (width x height)
# epoch_104_image_3.png: (512, 512) (width x height)
# epoch_108_image_0.png: (512, 512) (width x height)
# epoch_108_image_1.png: (512, 512) (width x height)
# epoch_108_image_2.png: (512, 512) (width x height)
# epoch_108_image_3.png: (512, 512) (width x height)
# epoch_112_image_0.png: (512, 512) (width x height)
# epoch_112_image_1.png: (512, 512) (width x height)
# epoch_112_image_2.png: (512, 512) (width x height)
# epoch_112_image_3.png: (512, 512) (width x height)
# epoch_116_image_0.png: (512, 512) (width x height)
# epoch_116_image_1.png: (512, 512) (width x height)
# epoch_116_image_2.png: (512, 512) (width x height)
# epoch_116_image_3.png: (512, 512) (width x height)
# epoch_120_image_0.png: (512, 512) (width x height)
# epoch_120_image_1.png: (512, 512) (width x height)
# epoch_120_image_2.png: (512, 512) (width x height)
# epoch_120_image_3.png: (512, 512) (width x height)
# epoch_124_image_0.png: (512, 512) (width x height)
# epoch_124_image_1.png: (512, 512) (width x height)
# epoch_124_image_2.png: (512, 512) (width x height)
# epoch_124_image_3.png: (512, 512) (width x height)
# epoch_128_image_0.png: (512, 512) (width x height)
# epoch_128_image_1.png: (512, 512) (width x height)
# epoch_128_image_2.png: (512, 512) (width x height)
# epoch_128_image_3.png: (512, 512) (width x height)
# epoch_132_image_0.png: (512, 512) (width x height)
# epoch_132_image_1.png: (512, 512) (width x height)
# epoch_132_image_2.png: (512, 512) (width x height)
# epoch_132_image_3.png: (512, 512) (width x height)
# epoch_136_image_0.png: (512, 512) (width x height)
# epoch_136_image_1.png: (512, 512) (width x height)
# epoch_136_image_2.png: (512, 512) (width x height)
# epoch_136_image_3.png: (512, 512) (width x height)
# epoch_36_image_0.png: (512, 512) (width x height)
# epoch_36_image_1.png: (512, 512) (width x height)
# epoch_36_image_2.png: (512, 512) (width x height)
# epoch_36_image_3.png: (512, 512) (width x height)
# epoch_40_image_0.png: (512, 512) (width x height)
# epoch_40_image_1.png: (512, 512) (width x height)
# epoch_40_image_2.png: (512, 512) (width x height)
# epoch_40_image_3.png: (512, 512) (width x height)
# epoch_44_image_0.png: (512, 512) (width x height)
# epoch_44_image_1.png: (512, 512) (width x height)
# epoch_44_image_2.png: (512, 512) (width x height)
# epoch_44_image_3.png: (512, 512) (width x height)
# epoch_48_image_0.png: (512, 512) (width x height)
# epoch_48_image_1.png: (512, 512) (width x height)
# epoch_48_image_2.png: (512, 512) (width x height)
# epoch_48_image_3.png: (512, 512) (width x height)
# epoch_52_image_0.png: (512, 512) (width x height)
# epoch_52_image_1.png: (512, 512) (width x height)
# epoch_52_image_2.png: (512, 512) (width x height)
# epoch_52_image_3.png: (512, 512) (width x height)
# epoch_56_image_0.png: (512, 512) (width x height)
# epoch_56_image_1.png: (512, 512) (width x height)
# epoch_56_image_2.png: (512, 512) (width x height)
# epoch_56_image_3.png: (512, 512) (width x height)
# epoch_60_image_0.png: (512, 512) (width x height)
# epoch_60_image_1.png: (512, 512) (width x height)
# epoch_60_image_2.png: (512, 512) (width x height)
# epoch_60_image_3.png: (512, 512) (width x height)
# epoch_64_image_0.png: (512, 512) (width x height)
# epoch_64_image_1.png: (512, 512) (width x height)
# epoch_64_image_2.png: (512, 512) (width x height)
# epoch_64_image_3.png: (512, 512) (width x height)
# epoch_68_image_0.png: (512, 512) (width x height)
# epoch_68_image_1.png: (512, 512) (width x height)
# epoch_68_image_2.png: (512, 512) (width x height)
# epoch_68_image_3.png: (512, 512) (width x height)
# epoch_72_image_0.png: (512, 512) (width x height)
# epoch_72_image_1.png: (512, 512) (width x height)
# epoch_72_image_2.png: (512, 512) (width x height)
# epoch_72_image_3.png: (512, 512) (width x height)
# epoch_76_image_0.png: (512, 512) (width x height)
# epoch_76_image_1.png: (512, 512) (width x height)
# epoch_76_image_2.png: (512, 512) (width x height)
# epoch_76_image_3.png: (512, 512) (width x height)
# epoch_80_image_0.png: (512, 512) (width x height)
# epoch_80_image_1.png: (512, 512) (width x height)
# epoch_80_image_2.png: (512, 512) (width x height)
# epoch_80_image_3.png: (512, 512) (width x height)
# epoch_84_image_0.png: (512, 512) (width x height)
# epoch_84_image_1.png: (512, 512) (width x height)
# epoch_84_image_2.png: (512, 512) (width x height)
# epoch_84_image_3.png: (512, 512) (width x height)
# epoch_88_image_0.png: (512, 512) (width x height)
# epoch_88_image_1.png: (512, 512) (width x height)
# epoch_88_image_2.png: (512, 512) (width x height)
# epoch_88_image_3.png: (512, 512) (width x height)
# epoch_92_image_0.png: (512, 512) (width x height)
# epoch_92_image_1.png: (512, 512) (width x height)
# epoch_92_image_2.png: (512, 512) (width x height)
# epoch_92_image_3.png: (512, 512) (width x height)
# epoch_96_image_0.png: (512, 512) (width x height)
# epoch_96_image_1.png: (512, 512) (width x height)
# epoch_96_image_2.png: (512, 512) (width x height)
# epoch_96_image_3.png: (512, 512) (width x height)
