# %% [markdown]
# # **Image Super-Resolution**
# **64x64 -> 512x512**
#
# A colab notebook for upscaling 64x64 images to 512x512, using [this](https://github.com/Janspiry/Image-Super-Resolution-via-Iterative-Refinement).

# %% [markdown]
# ## Setup
# ---
# Instructions:
#
# *   Turn on hardware acceleration under `Runtime -> Change Runtime Type -> Hardware accelerator -> GPU`
# *   Use this command to ensure that the connected machine has a GPU:

# %%
# !nvidia-smi --query-gpu=gpu_name,driver_version,memory.total --format=csv

# %% [markdown]
# *    Now, execute each cell sequentially, waiting until each one is done before running the next cell.

# %% [markdown]
# ### Clone repo, download a pre-trained model, install dependencies.

# %%
# %cd /Users/idilunlu/Desktop/sr3_trial
# !git clone https://github.com/Janspiry/Image-Super-Resolution-via-Iterative-Refinement.git
# !pip install tensorboardx
# Out:
# /Users/idilunlu/Desktop/sr3_trial
# fatal: destination path 'Image-Super-Resolution-via-Iterative-Refinement' already exists and is not an empty directory.
# Requirement already satisfied: tensorboardx in /Users/idilunlu/miniconda3/envs/upscaler/lib/python3.9/site-packages (2.6.2.2)
# Requirement already satisfied: numpy in /Users/idilunlu/miniconda3/envs/upscaler/lib/python3.9/site-packages (from tensorboardx) (1.26.4)
# Requirement already satisfied: packaging in /Users/idilunlu/miniconda3/envs/upscaler/lib/python3.9/site-packages (from tensorboardx) (24.0)
# Requirement already satisfied: protobuf>=3.20 in /Users/idilunlu/miniconda3/envs/upscaler/lib/python3.9/site-packages (from tensorboardx) (4.25.3)

# %% [markdown]
# **NOTE: The `gdown` command does not always work.** If it gives you an error, as a temporary workaround, you must manually upload files for the pre-trained model. Download the files [here](https://drive.google.com/drive/folders/1mCiWhFqHyjt5zE4IdA41fjFwCYdqDzSF) (you may have to log into your google account to be able to do so). Then, click the `files` button on the left hand side of the screen, and find the folder labled `Image-Super-Resolution-via-Iterative-Refinement`. Click the three dots on the right of the folder, and click `upload`. Now, select the model files that you downloaded.
#
# **ALTERNATIVELY: if you plan to use this script frequently, you can make a copy of the model files in your own google drive.** Go [here](https://drive.google.com/drive/folders/1mCiWhFqHyjt5zE4IdA41fjFwCYdqDzSF), right click on each file, and hit `Make a copy`. Next, locate the files in your own google drive, and rename them from `Copy of I830000_E32_opt.pth` and `Copy of I830000_E32_gen.pth` to `I830000_E32_opt.pth` and `I830000_E32_gen.pth`. Next, right click on each file, and hit `Get link`. Click on `Restricted`, and change it to `Anyone with the link...`, as `Viewer`. Now, copy the links. They should look something like this: `https://drive.google.com/file/d/<file id>/view?usp=sharing` - copy the ids, and paste them into the `gdown` commands below.
#
# For some reason, the model files are getting rate limited at times. This will hopefully be fixed in the future.

# %% [markdown]
# https://drive.google.com/file/d/1a-JznwsHmnCFhdWU041jaTZ4_ZQasJBk/view?usp=sharing
# https://drive.google.com/file/d/1iITtXn2cdNmJlldR88wIsr-FEFv8PDIQ/view?usp=sharing

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting beautifulsoup4 (from gdown)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: filelock in /Users/idilunlu/miniconda3/envs/upscaler/lib/python3.9/site-packages (from gdown) (3.14.0)
# Requirement already satisfied: requests[socks] in /Users/idilunlu/miniconda3/envs/upscaler/lib/python3.9/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /Users/idilunlu/miniconda3/envs/upscaler/lib/python3.9/site-packages (from gdown) (4.66.4)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/idilunlu/miniconda3/envs/upscaler/lib/python3.9/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/idilunlu/miniconda3/envs/upscaler/lib/python3.9/site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/idilunlu/miniconda3/envs/upscaler/lib/python3.9/site-packages (from requests[socks]->gdown) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/idilunlu/miniconda3/envs/upscaler/lib/python3.9/site-packages (from requests[socks]->gdown) (2024.2.2)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 350.8 kB/s eta 0:00:00a 0:00:01
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, PySocks, beautifulsoup4, gdown
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.12.3 gdown-5.2.0 soupsieve-2.5

# %%
# %cd /Users/idilunlu/Desktop/sr3_trial/Image-Super-Resolution-via-Iterative-Refinement/
# !gdown --id 1a-JznwsHmnCFhdWU041jaTZ4_ZQasJBk
# !gdown --id 1iITtXn2cdNmJlldR88wIsr-FEFv8PDIQ
# Out:
# /Users/idilunlu/Desktop/sr3_trial/Image-Super-Resolution-via-Iterative-Refinement
# /Users/idilunlu/miniconda3/envs/upscaler/lib/python3.9/site-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1a-JznwsHmnCFhdWU041jaTZ4_ZQasJBk
# From (redirected): https://drive.google.com/uc?id=1a-JznwsHmnCFhdWU041jaTZ4_ZQasJBk&confirm=t&uuid=29fe9140-344c-4999-acbf-1d5427e401e1
# To: /Users/idilunlu/Desktop/sr3_trial/Image-Super-Resolution-via-Iterative-Refinement/I830000_E32_gen.pth
# 100%|█████████████████████████████████████████| 622M/622M [13:53<00:00, 746kB/s]
# /Users/idilunlu/miniconda3/envs/upscaler/lib/python3.9/site-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1iITtXn2cdNmJlldR88wIsr-FEFv8PDIQ
# From (redirected): https://drive.google.com/uc?id=1iITtXn2cdNmJlldR88wIsr-FEFv8PDIQ&confirm=t&uuid=721f278f-fe6e-41d3-bddd-91de9d8a1afd
# To: /Users/idilunlu/Desktop/sr3_trial/Image-Super-Resolution-via-Iterative-Refinement/I830000_E32_opt.pth
# 100%|██████████████████████████████████████| 1.24G/1.24G [16:06<00:00, 1.29MB/s]
# [Errno 2] No such file or directory: '/content/Image-Super-Resolution-via-Iterative-Refinement/config/'
# /Users/idilunlu/Desktop/sr3_trial/Image-Super-Resolution-via-Iterative-Refinement

# %%
# %cd /Users/idilunlu/Desktop/sr3_trial/Image-Super-Resolution-via-Iterative-Refinement/config/
# Out:
# /Users/idilunlu/Desktop/sr3_trial/Image-Super-Resolution-via-Iterative-Refinement/config

# %% [markdown]
# ### Patch config files
#
# Create patchfile

# %%
# %%writefile 64_512.patch
# --- sr_sr3_64_512_new.json	2021-10-22 16:20:20.901133618 +0000
# +++ sr_sr3_64_512.json	2021-10-22 16:20:52.036081672 +0000
# @@ -9,8 +9,8 @@
#          "tb_logger": "tb_logger",
#          "results": "results",
#          "checkpoint": "checkpoint",
# -        "resume_state": null
# -        // "resume_state": "experiments/distributed_high_sr_ffhq_210901_121212/checkpoint/I830000_E32" //pretrain model or training state
# +        // "resume_state": null
# +        "resume_state": "I830000_E32" //pretrain model or training state
#      },
#      "datasets": {
#          "train": {
# Out:
# Overwriting 64_512.patch

# %% [markdown]
# Apply patchfile

# %%
# !brew install dos2unix
# !dos2unix sr_sr3_64_512.json
# !patch < 64_512.patch
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with HOMEBREW_AUTO_UPDATE_SECS or disable with
# HOMEBREW_NO_AUTO_UPDATE. Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Warning: No remote 'origin' in /opt/homebrew/Library/Taps/protortyp/homebrew-taps, skipping update!
# ==> Downloading https://ghcr.io/v2/homebrew/portable-ruby/portable-ruby/blobs/sha256:bbb73a9d86fa37128c54c74b020096a646c46c525fd5eb0c4a2467551fb2d377
# ######################################################################### 100.0%                          0.5%                                      11.8%                                    16.5%##                                     52.7%
# ==> Pouring portable-ruby-3.3.2.arm64_big_sur.bottle.tar.gz
# ==> Auto-updated Homebrew!
# ==> Updated Homebrew from 4.2.16 (fcc190b5c6) to 4.3.2 (fb81a6d874).
# Updated 3 taps (minio/stable, homebrew/core and homebrew/cask).
# ==> New Formulae
# ansible-creator            kubecolor                  podlet
# apache-flink-cdc           kubectl-cnpg               promptfoo
# autotrace                  kubectl-rook-ceph          qshell
# basti                      kubernetes-cli@1.29        rage
# beakerlib                  kuto                       redict
# beancount-language-server  kuzu                       river
# bigquery-emulator          lexido                     ronn-ng
# bootterm                   liblc3                     rust-parallel
# cahute                     libtickit                  rustcat
# chainhook                  libvirt-python             rustls-ffi
# cloudflare-cli4            llama.cpp                  sherlock
# descope                    llvm@17                    soapyremote
# dillo                      logdy                      span-lite
# displayplacer              mactop                     stripe-cli
# dpcmd                      mdformat                   stripe-mock
# espeak-ng                  mihomo                     superfile
# fastapi                    morpheus                   sysaidmin
# ffmpeg@6                   msieve                     task@2
# flawz                      navidrome                  tenv
# forbidden                  nextdns                    tmt
# gcc@13                     nvtop                      tofuenv
# go-size-analyzer           ocicl                      traefik@2
# godap                      oj                         uni-algo
# gorilla-cli                openfa                     uutils-diffutils
# haproxy@2.8                overarch                   valkey
# iamb                       parsedmarc                 vedic
# jsontoolkit                pedump
# kconf                      pnpm@8
# ==> New Casks
# 1password-cli@1                          font-meslo-for-powerlevel10k
# 1password-cli@beta                       font-meslo-for-powerline
# 1password@7                              font-meslo-lg
# 1password@beta                           font-meslo-lg-dz
# 1password@nightly                        font-meslo-lg-nerd-font
# ableton-live-intro@11                    font-metal
# ableton-live-lite@11                     font-metal-mania
# ableton-live-standard@11                 font-metamorphous
# ableton-live-suite@10                    font-metrophobic
# ableton-live-suite@11                    font-metropolis
# adguard-vpn@nightly                      font-miama
# adguard@nightly                          font-miao-unicode
# aerial@beta                              font-michroma
# affinity-designer@1                      font-micro-5
# affinity-photo@1                         font-micro-5-charted
# affinity-publisher@1                     font-migmix-1m
# alfred@4                                 font-migmix-1p
# android-studio-preview@beta              font-migmix-2m
# android-studio-preview@canary            font-migmix-2p
# anythingllm                              font-migu-1c
# arctic                                   font-migu-1m
# arduino-ide@nightly                      font-migu-1p
# arm-performance-libraries                font-migu-2m
# automattic-texts                         font-milonga
# azure-data-studio@insiders               font-miltonian
# bbedit@14                                font-miltonian-tattoo
# beyond-compare@beta                      font-mina
# bias-fx                                  font-mingzat
# blender@lts                              font-miniver
# blitz-gg                                 font-miriam-libre
# boltai                                   font-miriam-mono-clm
# brave-browser@beta                       font-mirza
# brave-browser@dev                        font-miss-fajardose
# brave-browser@nightly                    font-mitr
# buckets@beta                             font-mochiy-pop-one
# calibrite-profiler                       font-mochiy-pop-p-one
# canon-ufrii-driver                       font-modak
# carbon-copy-cloner@5                     font-modern-antiqua
# carbon-copy-cloner@6                     font-mogra
# chatgpt                                  font-mohave
# chime                                    font-moirai-one
# chromedriver@beta                        font-molengo
# core-tunnel                              font-molle
# corretto@11                              font-mona-sans
# corretto@17                              font-monaspace
# corretto@21                              font-monaspace-nerd-font
# corretto@8                               font-monda
# crystaldiffract                          font-monocraft
# crystalviewer                            font-monocraft-nerd-font
# darkmodebuddy                            font-monofett
# dash@6                                   font-monofur-for-powerline
# db-browser-for-sqlcipher@nightly         font-monofur-nerd-font
# db-browser-for-sqlite@nightly            font-monoid
# deadbeef@nightly                         font-monoid-nerd-font
# defold@alpha                             font-monoisome
# defold@beta                              font-monomaniac-one
# discord@canary                           font-mononoki
# discord@development                      font-mononoki-nerd-font
# discord@ptb                              font-monoton
# dolphin@beta                             font-monsieur-la-doulaise
# dolphin@dev                              font-montaga
# dotnet-sdk@preview                       font-montagu-slab
# dotnet@preview                           font-montecarlo
# dropbox@beta                             font-montez
# element@nightly                          font-montserrat
# elephas@beta                             font-montserrat-alternates
# emacs@nightly                            font-montserrat-subrayada
# emacs@pretest                            font-moo-lah-lah
# ente-auth                                font-mooli
# figma@beta                               font-moon-dance
# firefox@beta                             font-moul
# firefox@cn                               font-moulpali
# firefox@developer-edition                font-mountains-of-christmas
# firefox@esr                              font-mouse-memoirs
# firefox@nightly                          font-mplus
# flox                                     font-mplus-nerd-font
# folding-at-home@beta                     font-mr-bedfort
# font-0xproto                             font-mr-dafoe
# font-0xproto-nerd-font                   font-mr-de-haviland
# font-3270                                font-mrs-saint-delafield
# font-3270-nerd-font                      font-mrs-sheppards
# font-437-plus                            font-ms-madi
# font-abeezee                             font-mukta
# font-abel                                font-mukta-mahee
# font-abhaya-libre                        font-mukta-malar
# font-aboreto                             font-mukta-vaani
# font-aboriginal-sans                     font-mukti-narrow
# font-aboriginal-serif                    font-mulish
# font-abril-fatface                       font-murecho
# font-abyssinica-sil                      font-museo
# font-academicons                         font-museomoderno
# font-aclonica                            font-my-soul
# font-acme                                font-myanmar-sans-pro
# font-actor                               font-mynerve
# font-adamina                             font-myrica
# font-adinatha-tamil-brahmi               font-myricam
# font-adlam-display                       font-mystery-quest
# font-adobe-blank                         font-n-gage
# font-advent-pro                          font-nabla
# font-afacad                              font-namdhinggo
# font-african-sans                        font-nanum-brush-script
# font-african-serif                       font-nanum-gothic
# font-agave-nerd-font                     font-nanum-gothic-coding
# font-agbalumo                            font-nanum-myeongjo
# font-agdasima                            font-nanum-pen-script
# font-aguafina-script                     font-narnoor
# font-ahuramzda                           font-national-park
# font-aileron                             font-nats
# font-akatab                              font-neonderthaw
# font-akaya-kanadaka                      font-nerko-one
# font-akaya-telivigala                    font-neucha
# font-akronim                             font-neuton
# font-aksara-bali-galang                  font-new-rocker
# font-akshar                              font-new-tegomin
# font-aladin                              font-new-york
# font-alata                               font-news-cycle
# font-alatsi                              font-newsreader
# font-albert-sans                         font-nico-moji
# font-albertella                          font-niconne
# font-aldrich                             font-nikukyu
# font-alef                                font-nimbus-sans-l
# font-alegreya                            font-niramit
# font-alegreya-sans                       font-nixie-one
# font-alegreya-sans-sc                    font-nobile
# font-alegreya-sc                         font-nokora
# font-aleo                                font-norican
# font-alex-brush                          font-nosifer
# font-alexandria                          font-nosifer-caps
# font-alfa-slab-one                       font-notable
# font-alice                               font-nothing-you-could-do
# font-alike                               font-noticia-text
# font-alike-angular                       font-noto-color-emoji
# font-alkalami                            font-noto-color-emoji-compat-test
# font-alkatra                             font-noto-emoji
# font-allan                               font-noto-kufi-arabic
# font-allerta                             font-noto-mono
# font-allerta-stencil                     font-noto-mono-for-powerline
# font-allison                             font-noto-music
# font-allura                              font-noto-naskh-arabic
# font-almarai                             font-noto-naskh-arabic-ui
# font-almendra                            font-noto-nastaliq-urdu
# font-almendra-display                    font-noto-nerd-font
# font-almendra-sc                         font-noto-rashi-hebrew
# font-alumni-sans                         font-noto-sans
# font-alumni-sans-collegiate-one          font-noto-sans-adlam
# font-alumni-sans-collegiate-one-sc       font-noto-sans-adlam-unjoined
# font-alumni-sans-inline-one              font-noto-sans-anatolian-hieroglyphs
# font-alumni-sans-pinstripe               font-noto-sans-arabic
# font-amarante                            font-noto-sans-arabic-ui
# font-amaranth                            font-noto-sans-armenian
# font-amatic-sc                           font-noto-sans-avestan
# font-amethysta                           font-noto-sans-balinese
# font-amiko                               font-noto-sans-bamum
# font-amiri                               font-noto-sans-bassa-vah
# font-amiri-quran                         font-noto-sans-batak
# font-amita                               font-noto-sans-bengali
# font-amstelvar-alpha                     font-noto-sans-bengali-ui
# font-anaheim                             font-noto-sans-bhaiksuki
# font-andada-pro                          font-noto-sans-brahmi
# font-andagii                             font-noto-sans-buginese
# font-andale-mono                         font-noto-sans-buhid
# font-andika                              font-noto-sans-canadian-aboriginal
# font-andron-scriptor-web                 font-noto-sans-carian
# font-anek-bangla                         font-noto-sans-caucasian-albanian
# font-anek-devanagari                     font-noto-sans-chakma
# font-anek-gujarati                       font-noto-sans-cham
# font-anek-gurmukhi                       font-noto-sans-cherokee
# font-anek-kannada                        font-noto-sans-chorasmian
# font-anek-latin                          font-noto-sans-cjk
# font-anek-malayalam                      font-noto-sans-cjk-hk
# font-anek-odia                           font-noto-sans-cjk-jp
# font-anek-tamil                          font-noto-sans-cjk-kr
# font-anek-telugu                         font-noto-sans-cjk-sc
# font-angkor                              font-noto-sans-cjk-tc
# font-anka-coder                          font-noto-sans-coptic
# font-annapurna-sil                       font-noto-sans-cuneiform
# font-annie-use-your-telescope            font-noto-sans-cypriot
# font-anonymice-nerd-font                 font-noto-sans-cypro-minoan
# font-anonymice-powerline                 font-noto-sans-deseret
# font-anonymous-pro                       font-noto-sans-devanagari
# font-anta                                font-noto-sans-devanagari-ui
# font-antic                               font-noto-sans-display
# font-antic-didone                        font-noto-sans-duployan
# font-antic-slab                          font-noto-sans-egyptian-hieroglyphs
# font-antinoou                            font-noto-sans-elbasan
# font-anton                               font-noto-sans-elymaic
# font-anton-sc                            font-noto-sans-ethiopic
# font-antonio                             font-noto-sans-georgian
# font-anuphan                             font-noto-sans-glagolitic
# font-anybody                             font-noto-sans-gothic
# font-aoboshi-one                         font-noto-sans-grantha
# font-ar-one-sans                         font-noto-sans-gujarati
# font-arapey                              font-noto-sans-gujarati-ui
# font-arbutus                             font-noto-sans-gunjala-gondi
# font-arbutus-slab                        font-noto-sans-gurmukhi
# font-architects-daughter                 font-noto-sans-gurmukhi-ui
# font-architype-renner                    font-noto-sans-hanifi-rohingya
# font-archivo                             font-noto-sans-hanunoo
# font-archivo-black                       font-noto-sans-hatran
# font-archivo-narrow                      font-noto-sans-hebrew
# font-are-you-serious                     font-noto-sans-hk
# font-aref-ruqaa                          font-noto-sans-imperial-aramaic
# font-aref-ruqaa-ink                      font-noto-sans-indic-siyaq-numbers
# font-arial                               font-noto-sans-inscriptional-pahlavi
# font-arial-black                         font-noto-sans-inscriptional-parthian
# font-arima                               font-noto-sans-javanese
# font-arimo                               font-noto-sans-jp
# font-arimo-nerd-font                     font-noto-sans-kaithi
# font-arizonia                            font-noto-sans-kannada
# font-ark-pixel-10px-monospaced           font-noto-sans-kannada-ui
# font-ark-pixel-10px-proportional         font-noto-sans-kawi
# font-ark-pixel-12px-monospaced           font-noto-sans-kayah-li
# font-ark-pixel-12px-proportional         font-noto-sans-kharoshthi
# font-ark-pixel-16px-monospaced           font-noto-sans-khmer
# font-ark-pixel-16px-proportional         font-noto-sans-khmer-ui
# font-armata                              font-noto-sans-khojki
# font-arsenal                             font-noto-sans-khudawadi
# font-arsenal-sc                          font-noto-sans-kr
# font-artifika                            font-noto-sans-lao
# font-arvo                                font-noto-sans-lao-looped
# font-arya                                font-noto-sans-lao-ui
# font-asap                                font-noto-sans-lepcha
# font-asap-condensed                      font-noto-sans-limbu
# font-asar                                font-noto-sans-linear-a
# font-asset                               font-noto-sans-linear-b
# font-assistant                           font-noto-sans-lisu
# font-astloch                             font-noto-sans-lycian
# font-asul                                font-noto-sans-lydian
# font-athiti                              font-noto-sans-mahajani
# font-atkinson-hyperlegible               font-noto-sans-malayalam
# font-atma                                font-noto-sans-malayalam-ui
# font-atomic-age                          font-noto-sans-mandaic
# font-aubrey                              font-noto-sans-manichaean
# font-audiowide                           font-noto-sans-marchen
# font-aurulent-sans-mono-nerd-font        font-noto-sans-masaram-gondi
# font-autour-one                          font-noto-sans-math
# font-average                             font-noto-sans-mayan-numerals
# font-average-mono                        font-noto-sans-medefaidrin
# font-average-sans                        font-noto-sans-meetei-mayek
# font-averia-gruesa-libre                 font-noto-sans-mende-kikakui
# font-averia-libre                        font-noto-sans-meroitic
# font-averia-sans-libre                   font-noto-sans-miao
# font-averia-serif-libre                  font-noto-sans-modi
# font-awesome-terminal-fonts              font-noto-sans-mongolian
# font-azeret-mono                         font-noto-sans-mono
# font-azonix                              font-noto-sans-mono-cjk-hk
# font-b612                                font-noto-sans-mono-cjk-jp
# font-b612-mono                           font-noto-sans-mono-cjk-kr
# font-babylonica                          font-noto-sans-mono-cjk-sc
# font-bacasime-antique                    font-noto-sans-mono-cjk-tc
# font-bad-script                          font-noto-sans-mro
# font-bagel-fat-one                       font-noto-sans-multani
# font-bahiana                             font-noto-sans-myanmar
# font-bahianita                           font-noto-sans-myanmar-ui
# font-bai-jamjuree                        font-noto-sans-n-ko
# font-bakbak-one                          font-noto-sans-nabataean
# font-ballet                              font-noto-sans-nag-mundari
# font-baloo                               font-noto-sans-nandinagari
# font-baloo-2                             font-noto-sans-new-tai-lue
# font-baloo-bhai-2                        font-noto-sans-newa
# font-baloo-bhaijaan-2                    font-noto-sans-nko
# font-baloo-bhaina-2                      font-noto-sans-nko-unjoined
# font-baloo-chettan-2                     font-noto-sans-nushu
# font-baloo-da-2                          font-noto-sans-ogham
# font-baloo-paaji-2                       font-noto-sans-ol-chiki
# font-baloo-tamma-2                       font-noto-sans-old-hungarian
# font-baloo-tammudu-2                     font-noto-sans-old-italic
# font-baloo-thambi-2                      font-noto-sans-old-north-arabian
# font-balsamiq-sans                       font-noto-sans-old-permic
# font-balthazar                           font-noto-sans-old-persian
# font-bangers                             font-noto-sans-old-sogdian
# font-barlow                              font-noto-sans-old-south-arabian
# font-barlow-condensed                    font-noto-sans-old-turkic
# font-barlow-semi-condensed               font-noto-sans-oriya
# font-barriecito                          font-noto-sans-oriya-ui
# font-barrio                              font-noto-sans-osage
# font-basic                               font-noto-sans-osmanya
# font-baskervville                        font-noto-sans-pahawh-hmong
# font-baskervville-sc                     font-noto-sans-palmyrene
# font-battambang                          font-noto-sans-pau-cin-hau
# font-baumans                             font-noto-sans-phags-pa
# font-bayon                               font-noto-sans-phagspa
# font-be-vietnam-pro                      font-noto-sans-phoenician
# font-beau-rivage                         font-noto-sans-psalter-pahlavi
# font-bebas-neue                          font-noto-sans-rejang
# font-belanosima                          font-noto-sans-runic
# font-belgrano                            font-noto-sans-samaritan
# font-bellefair                           font-noto-sans-saurashtra
# font-belleza                             font-noto-sans-sc
# font-bellota                             font-noto-sans-sharada
# font-bellota-text                        font-noto-sans-shavian
# font-benchnine                           font-noto-sans-siddham
# font-benne                               font-noto-sans-signwriting
# font-bentham                             font-noto-sans-sinhala
# font-berkshire-swash                     font-noto-sans-sinhala-ui
# font-besley                              font-noto-sans-sogdian
# font-beth-ellen                          font-noto-sans-sora-sompeng
# font-bevan                               font-noto-sans-soyombo
# font-bhavuka                             font-noto-sans-sundanese
# font-bhutuka-expanded-one                font-noto-sans-syloti-nagri
# font-big-shoulders-display               font-noto-sans-symbols
# font-big-shoulders-inline-display        font-noto-sans-symbols-2
# font-big-shoulders-inline-text           font-noto-sans-syriac
# font-big-shoulders-stencil-display       font-noto-sans-syriac-eastern
# font-big-shoulders-stencil-text          font-noto-sans-syriac-estrangela
# font-big-shoulders-text                  font-noto-sans-syriac-western
# font-bigblue-terminal-nerd-font          font-noto-sans-tagalog
# font-bigelow-rules                       font-noto-sans-tagbanwa
# font-bigshot-one                         font-noto-sans-tai-le
# font-bilbo                               font-noto-sans-tai-tham
# font-bilbo-swash-caps                    font-noto-sans-tai-viet
# font-biorhyme                            font-noto-sans-takri
# font-biorhyme-expanded                   font-noto-sans-tamil
# font-birthstone                          font-noto-sans-tamil-supplement
# font-birthstone-bounce                   font-noto-sans-tamil-ui
# font-biryani                             font-noto-sans-tangsa
# font-bitstream-vera                      font-noto-sans-tc
# font-bitstream-vera-sans-mono-nerd-font  font-noto-sans-telugu
# font-bitter                              font-noto-sans-telugu-ui
# font-bitter-ht                           font-noto-sans-thaana
# font-biz-udgothic                        font-noto-sans-thai
# font-biz-udmincho                        font-noto-sans-thai-looped
# font-biz-udpgothic                       font-noto-sans-thai-ui
# font-biz-udpmincho                       font-noto-sans-tibetan
# font-black-and-white-picture             font-noto-sans-tifinagh
# font-black-han-sans                      font-noto-sans-tirhuta
# font-black-ops-one                       font-noto-sans-ugaritic
# font-blackout                            font-noto-sans-vai
# font-blaka                               font-noto-sans-vithkuqi
# font-blaka-hollow                        font-noto-sans-wancho
# font-blaka-ink                           font-noto-sans-warang-citi
# font-blex-mono-nerd-font                 font-noto-sans-yi
# font-blinker                             font-noto-sans-zanabazar-square
# font-blokk-neue                          font-noto-serif
# font-bm                                  font-noto-serif-ahom
# font-bodoni-moda                         font-noto-serif-armenian
# font-bodoni-moda-sc                      font-noto-serif-balinese
# font-bokor                               font-noto-serif-bengali
# font-bona-nova                           font-noto-serif-cjk
# font-bona-nova-sc                        font-noto-serif-cjk-hk
# font-bonbon                              font-noto-serif-cjk-jp
# font-bonheur-royale                      font-noto-serif-cjk-kr
# font-boogaloo                            font-noto-serif-cjk-sc
# font-borel                               font-noto-serif-cjk-tc
# font-bowlby-one                          font-noto-serif-devanagari
# font-bowlby-one-sc                       font-noto-serif-display
# font-braah-one                           font-noto-serif-dogra
# font-brawler                             font-noto-serif-ethiopic
# font-bree-serif                          font-noto-serif-georgian
# font-bricolage-grotesque                 font-noto-serif-grantha
# font-briem-hand                          font-noto-serif-gujarati
# font-brill                               font-noto-serif-gurmukhi
# font-bruno-ace                           font-noto-serif-hebrew
# font-bruno-ace-sc                        font-noto-serif-hentaigana
# font-brygada-1918                        font-noto-serif-hk
# font-bubblegum-sans                      font-noto-serif-jp
# font-bubbler-one                         font-noto-serif-kannada
# font-buda                                font-noto-serif-khitan-small-script
# font-buenard                             font-noto-serif-khmer
# font-bukyvede-bold                       font-noto-serif-khojki
# font-bukyvede-italic                     font-noto-serif-kr
# font-bukyvede-regular                    font-noto-serif-lao
# font-bungee                              font-noto-serif-makasar
# font-bungee-color                        font-noto-serif-malayalam
# font-bungee-hairline                     font-noto-serif-myanmar
# font-bungee-inline                       font-noto-serif-np-hmong
# font-bungee-outline                      font-noto-serif-nyiakeng-puachue-hmong
# font-bungee-shade                        font-noto-serif-old-uyghur
# font-bungee-spice                        font-noto-serif-oriya
# font-butcherman                          font-noto-serif-ottoman-siyaq
# font-butterfly-kids                      font-noto-serif-sc
# font-cabin                               font-noto-serif-sinhala
# font-cabin-condensed                     font-noto-serif-tamil
# font-cabin-sketch                        font-noto-serif-tangut
# font-cactus-classical-serif              font-noto-serif-tc
# font-caesar-dressing                     font-noto-serif-telugu
# font-cagliostro                          font-noto-serif-thai
# font-cairo                               font-noto-serif-tibetan
# font-cairo-play                          font-noto-serif-toto
# font-cal-sans                            font-noto-serif-vithkuqi
# font-caladea                             font-noto-serif-yezidi
# font-calistoga                           font-noto-traditional-nushu
# font-calligraffitti                      font-noto-znamenny-musical-notation
# font-cambay                              font-nova-cut
# font-cambo                               font-nova-flat
# font-camingocode                         font-nova-mono
# font-candal                              font-nova-oval
# font-cantarell                           font-nova-round
# font-cantata-one                         font-nova-script
# font-cantora-one                         font-nova-slim
# font-caprasimo                           font-nova-square
# font-capriola                            font-ntr
# font-caramel                             font-numans
# font-carattere                           font-nunito
# font-cardo                               font-nunito-sans
# font-carlito                             font-nuosu-sil
# font-carme                               font-ocr
# font-carrois-gothic                      font-odibee-sans
# font-carrois-gothic-sc                   font-odor-mean-chey
# font-carter-one                          font-office-code-pro
# font-cascadia-code                       font-offside
# font-cascadia-code-nf                    font-ofl-sorts-mill-goudy-tt
# font-cascadia-code-pl                    font-oi
# font-cascadia-mono                       font-ojuju
# font-cascadia-mono-nf                    font-old-standard-tt
# font-cascadia-mono-pl                    font-oldenburg
# font-caskaydia-cove-nerd-font            font-ole
# font-caskaydia-mono-nerd-font            font-oleo-script
# font-castoro                             font-oleo-script-swash-caps
# font-castoro-titling                     font-onest
# font-catamaran                           font-oooh-baby
# font-caudex                              font-open-dyslexic
# font-caveat                              font-open-dyslexic-nerd-font
# font-caveat-brush                        font-open-iconic
# font-cedarville-cursive                  font-open-sans
# font-ceviche-one                         font-open-sans-hebrew
# font-chakra-petch                        font-open-sans-hebrew-condensed
# font-changa                              font-oppo-sans
# font-changa-one                          font-optician-sans
# font-chango                              font-oranienbaum
# font-chapbook                            font-orbit
# font-charis-sil                          font-orbitron
# font-charm                               font-oregano
# font-charmonman                          font-orelega-one
# font-charter                             font-orienta
# font-chathura                            font-original-surfer
# font-chau-philomene-one                  font-ostrich-sans
# font-chela-one                           font-oswald
# font-chelsea-market                      font-otomanopee-one
# font-chenla                              font-outfit
# font-chenyuluoyan                        font-over-the-rainbow
# font-cherish                             font-overlock
# font-cherry-bomb-one                     font-overlock-sc
# font-cherry-cream-soda                   font-overpass
# font-cherry-swash                        font-overpass-mono
# font-chewy                               font-overpass-nerd-font
# font-chiayi-city                         font-overused-grotesk
# font-chicle                              font-ovo
# font-chilanka                            font-oxanium
# font-chiron-hei-hk                       font-oxygen
# font-chiron-sung-hk                      font-oxygen-mono
# font-chivo                               font-pacifico
# font-chivo-mono                          font-padauk
# font-chocolate-classical-sans            font-padyakke-expanded-one
# font-chokokutai                          font-palanquin
# font-chomsky                             font-palanquin-dark
# font-chonburi                            font-palette-mosaic
# font-church-slavonic                     font-pangolin
# font-cica                                font-paprika
# font-cinzel                              font-parisienne
# font-cinzel-decorative                   font-passero-one
# font-clear-sans                          font-passion-one
# font-clicker-script                      font-passions-conflict
# font-climate-crisis                      font-pathway-extreme
# font-cochineal                           font-pathway-gothic-one
# font-coda                                font-patrick-hand
# font-code-new-roman-nerd-font            font-patrick-hand-sc
# font-code2002                            font-pattaya
# font-codicon                             font-patua-one
# font-codystar                            font-pavanam
# font-coelacanth                          font-paytone-one
# font-coiny                               font-peddana
# font-combo                               font-peralta
# font-comfortaa                           font-permanent-marker
# font-comforter                           font-petemoss
# font-comforter-brush                     font-petit-formal-script
# font-comic-mono                          font-petrona
# font-comic-neue                          font-phetsarath
# font-comic-sans-ms                       font-philosopher
# font-comic-shanns-mono-nerd-font         font-photonico-code
# font-coming-soon                         font-phudu
# font-comme                               font-piazzolla
# font-commissioner                        font-piedra
# font-commit-mono                         font-pigmo00
# font-commit-mono-nerd-font               font-pigmo01
# font-computer-modern                     font-pinyon-script
# font-conakry                             font-pirata-one
# font-concert-one                         font-pixelify-sans
# font-condiment                           font-plangothic
# font-consolas-for-powerline              font-plaster
# font-constructium                        font-platypi
# font-content                             font-play
# font-contrail-one                        font-playball
# font-convergence                         font-playfair
# font-cookie                              font-playfair-display
# font-cooper-hewitt                       font-playfair-display-sc
# font-copse                               font-playpen-sans
# font-corben                              font-playwrite-au-nsw
# font-corinthia                           font-playwrite-au-qld
# font-cormorant                           font-playwrite-au-sa
# font-cormorant-garamond                  font-playwrite-au-tas
# font-cormorant-infant                    font-playwrite-au-vic
# font-cormorant-sc                        font-playwrite-br
# font-cormorant-unicase                   font-playwrite-ca
# font-cormorant-upright                   font-playwrite-co
# font-courgette                           font-playwrite-de-grund
# font-courier-new                         font-playwrite-de-la
# font-courier-prime                       font-playwrite-de-sas
# font-courier-prime-code                  font-playwrite-de-va
# font-courier-prime-medium-and-semi-bold  font-playwrite-es
# font-courier-prime-sans                  font-playwrite-es-deco
# font-cousine                             font-playwrite-fr-moderne
# font-cousine-nerd-font                   font-playwrite-fr-trad
# font-coustard                            font-playwrite-gb-j
# font-covered-by-your-grace               font-playwrite-gb-s
# font-cozette                             font-playwrite-id
# font-crafty-girls                        font-playwrite-ie
# font-creepster                           font-playwrite-in
# font-creepster-caps                      font-playwrite-is
# font-crete-round                         font-playwrite-it-moderna
# font-crimson-pro                         font-playwrite-it-trad
# font-crimson-text                        font-playwrite-mx
# font-croissant-one                       font-playwrite-ng-modern
# font-crushed                             font-playwrite-nl
# font-cubic-11                            font-playwrite-no
# font-cuprum                              font-playwrite-nz
# font-cute-font                           font-playwrite-pl
# font-cutive                              font-playwrite-pt
# font-cutive-mono                         font-playwrite-ro
# font-d2coding                            font-playwrite-sk
# font-d2coding-nerd-font                  font-playwrite-tz
# font-daddy-time-mono-nerd-font           font-playwrite-us-modern
# font-dai-banna-sil                       font-playwrite-us-trad
# font-damion                              font-playwrite-vn
# font-dancing-script                      font-playwrite-za
# font-danfo                               font-plemol-jp
# font-dangrek                             font-plemol-jp-hs
# font-darker-grotesque                    font-plemol-jp-nf
# font-darumadrop-one                      font-plus-jakarta-sans
# font-darwin                              font-podkova
# font-dashicons                           font-podkova-vf-beta
# font-david-clm                           font-poetsen-one
# font-david-libre                         font-poiret-one
# font-dawning-of-a-new-day                font-poller-one
# font-days-one                            font-poltawski-nowy
# font-decovar-alpha                       font-poly
# font-dejavu                              font-pompiere
# font-dejavu-sans-mono-for-powerline      font-ponnala
# font-dejavu-sans-mono-nerd-font          font-pontano-sans
# font-dekko                               font-poor-story
# font-dela-gothic-one                     font-poppins
# font-delicious-handrawn                  font-poppins-latin
# font-delius                              font-poprumcute
# font-delius-swash-caps                   font-port-lligat-sans
# font-delius-unicase                      font-port-lligat-slab
# font-della-respira                       font-porter-sans-block
# font-delugia-book                        font-potta-one
# font-delugia-complete                    font-powerline-symbols
# font-delugia-mono-complete               font-pragati-narrow
# font-delugia-mono-powerline              font-praise
# font-delugia-powerline                   font-prata
# font-denk-one                            font-preahvihear
# font-devicons                            font-press-start-2p
# font-devonshire                          font-pretendard
# font-dhurjati                            font-pretendard-jp
# font-dhyana                              font-pretendard-std
# font-didact-gothic                       font-pridi
# font-digital-numbers                     font-princess-sofia
# font-digohweli-old-do                    font-prociono
# font-diphylleia                          font-profont-nerd-font
# font-diplomata                           font-profontx
# font-diplomata-sc                        font-proggy-clean-tt-nerd-font
# font-dm-mono                             font-prompt
# font-dm-sans                             font-prosto-one
# font-dm-serif-display                    font-protest-guerrilla
# font-dm-serif-text                       font-protest-revolution
# font-do-hyeon                            font-protest-riot
# font-dokdo                               font-protest-strike
# font-domine                              font-proza-libre
# font-donegal-one                         font-pt-mono
# font-dongle                              font-pt-sans
# font-doppio-one                          font-pt-sans-caption
# font-dorsa                               font-pt-sans-narrow
# font-dosis                               font-pt-serif
# font-dotgothic16                         font-pt-serif-caption
# font-doulos-sil                          font-public-sans
# font-dr-sugiyama                         font-puppies-play
# font-dream-han-sans                      font-puritan
# font-droid-sans-mono-for-powerline       font-purple-purse
# font-droid-sans-mono-nerd-font           font-pushster
# font-duru-sans                           font-qahiri
# font-dynalight                           font-quando
# font-dynapuff                            font-quantico
# font-eagle-lake                          font-quattrocento
# font-east-sea-dokdo                      font-quattrocento-sans
# font-eater                               font-questrial
# font-eb-garamond                         font-quicksand
# font-ebh                                 font-quintessential
# font-economica                           font-qwigley
# font-eczar                               font-qwitcher-grypen
# font-edlo                                font-racing-sans-one
# font-edu-nsw-act-foundation              font-radio-canada
# font-edu-qld-beginner                    font-radio-canada-big
# font-edu-sa-beginner                     font-radley
# font-edu-tas-beginner                    font-rajdhani
# font-edu-vic-wa-nt-beginner              font-rakkas
# font-edwin                               font-raleway
# font-el-messiri                          font-raleway-dots
# font-electrolize                         font-ramabhadra
# font-elice-digital-baeum                 font-ramaraja
# font-elsie                               font-rambla
# font-elsie-swash-caps                    font-rammetto-one
# font-elstobd                             font-rampart-one
# font-emblema-one                         font-ranchers
# font-emilys-candy                        font-rancho
# font-encode-sans                         font-ranga
# font-encode-sans-condensed               font-rasa
# font-encode-sans-expanded                font-rationale
# font-encode-sans-sc                      font-ravi-prakash
# font-encode-sans-semi-condensed          font-readex-pro
# font-encode-sans-semi-expanded           font-recursive
# font-engagement                          font-recursive-code
# font-englebert                           font-recursive-mono-nerd-font
# font-enriqueta                           font-red-hat-display
# font-envy-code-r                         font-red-hat-mono
# font-envy-code-r-nerd-font               font-red-hat-text
# font-ephesis                             font-red-rose
# font-epilogue                            font-redacted
# font-erica-one                           font-redacted-script
# font-escumasia                           font-reddit-mono
# font-esteban                             font-reddit-sans
# font-estonia                             font-reddit-sans-condensed
# font-et-book                             font-redhat
# font-euphoria-script                     font-redressed
# font-everson-mono                        font-reem-kufi
# font-ewert                               font-reem-kufi-fun
# font-exo                                 font-reem-kufi-ink
# font-exo-2                               font-reenie-beanie
# font-expletus-sans                       font-reggae-one
# font-explora                             font-rem
# font-ezra-sil                            font-rethink-sans
# font-fahkwang                            font-revalia
# font-fairfax                             font-rhodium-libre
# font-familjen-grotesk                    font-ribeye
# font-fandol                              font-ribeye-marrow
# font-fantasque-sans-mono                 font-ricty-diminished
# font-fantasque-sans-mono-nerd-font       font-righteous
# font-fantasque-sans-mono-noloopk         font-risque
# font-fanwood-text                        font-road-rage
# font-farro                               font-roboto
# font-farsan                              font-roboto-condensed
# font-fascinate                           font-roboto-flex
# font-fascinate-inline                    font-roboto-mono
# font-faster-one                          font-roboto-mono-for-powerline
# font-fasthand                            font-roboto-mono-nerd-font
# font-fauna-one                           font-roboto-serif
# font-faune                               font-roboto-slab
# font-faustina                            font-rochester
# font-federant                            font-rock-3d
# font-federo                              font-rock-salt
# font-felipa                              font-rocknroll-one
# font-fenix                               font-rokkitt
# font-festive                             font-rokkitt-vf-beta
# font-figtree                             font-romanesco
# font-finger-paint                        font-ronde
# font-finlandica                          font-ropa-sans
# font-fira-code                           font-rosario
# font-fira-code-nerd-font                 font-rosarivo
# font-fira-mono                           font-rouge-script
# font-fira-mono-for-powerline             font-rounded-mplus
# font-fira-mono-nerd-font                 font-routed-gothic
# font-fira-sans                           font-rowdies
# font-fira-sans-condensed                 font-rozha-one
# font-fira-sans-extra-condensed           font-rubik
# font-firago                              font-rubik-80s-fade
# font-firge                               font-rubik-beastly
# font-firgenerd                           font-rubik-broken-fax
# font-fjalla-one                          font-rubik-bubbles
# font-fjord-one                           font-rubik-burned
# font-flamenco                            font-rubik-dirt
# font-flavors                             font-rubik-distressed
# font-fleur-de-leah                       font-rubik-doodle-shadow
# font-flow-block                          font-rubik-doodle-triangles
# font-flow-circular                       font-rubik-gemstones
# font-flow-rounded                        font-rubik-glitch
# font-foldit                              font-rubik-glitch-pop
# font-fondamento                          font-rubik-iso
# font-fontawesome                         font-rubik-lines
# font-fontdiner-swanky                    font-rubik-maps
# font-forum                               font-rubik-marker-hatch
# font-foundation-icons                    font-rubik-maze
# font-foundry-sterling                    font-rubik-microbe
# font-fragment-mono                       font-rubik-mono-one
# font-francois-one                        font-rubik-moonrocks
# font-frank-ruhl-libre                    font-rubik-one
# font-fraunces                            font-rubik-pixels
# font-freckle-face                        font-rubik-puddles
# font-fredericka-the-great                font-rubik-scribble
# font-fredoka                             font-rubik-spray-paint
# font-free-mono-tengwar                   font-rubik-storm
# font-freefont                            font-rubik-vinyl
# font-freehand                            font-rubik-wet-paint
# font-freeman                             font-ruda
# font-fresca                              font-rufina
# font-frijole                             font-ruge-boogie
# font-fruktur                             font-ruluko
# font-fugaz-one                           font-rum-raisin
# font-fuggles                             font-ruslan-display
# font-fuzzy-bubbles                       font-russo-one
# font-fzfangsong-z02                      font-ruthie
# font-fzkai-z03                           font-ruwudu
# font-fzshusong-z01                       font-rye
# font-fzxiaobiaosong-b05                  font-sacramento
# font-gabarito                            font-sahitya
# font-gabriela                            font-sail
# font-gaegu                               font-saira
# font-gafata                              font-saira-condensed
# font-gajraj-one                          font-saira-extra-condensed
# font-galada                              font-saira-semi-condensed
# font-galdeano                            font-saira-stencil-one
# font-galindo                             font-salsa
# font-gamja-flower                        font-sanchez
# font-gandhi-sans                         font-sancreek
# font-gantari                             font-sankofa-display
# font-gasoek-one                          font-sans-forgetica
# font-gayathri                            font-sansation
# font-geist                               font-sansita
# font-geist-mono                          font-sansita-one
# font-geist-mono-nerd-font                font-sansita-swashed
# font-gelasio                             font-sarabun
# font-gemunu-libre                        font-sarala
# font-genjyuugothic                       font-sarasa-gothic
# font-genjyuugothic-l                     font-sarina
# font-genjyuugothic-x                     font-sarpanch
# font-genos                               font-sassy-frass
# font-genryumin                           font-satisfy
# font-gensekigothic                       font-sauce-code-pro-nerd-font
# font-gensenrounded                       font-sawarabi-gothic
# font-genshingothic                       font-sawarabi-mincho
# font-gentium-basic                       font-scada
# font-gentium-book-basic                  font-scheherazade
# font-gentium-book-plus                   font-scheherazade-new
# font-gentium-plus                        font-schibsted-grotesk
# font-genwanmin                           font-schoolbell
# font-genyogothic                         font-scope-one
# font-genyomin                            font-seaweed-script
# font-geo                                 font-secular-one
# font-geologica                           font-sedan
# font-georama                             font-sedan-sc
# font-georgia                             font-sedgwick-ave
# font-geostar                             font-sedgwick-ave-display
# font-geostar-fill                        font-sen
# font-germania-one                        font-send-flowers
# font-gfs-didot                           font-sevillana
# font-gfs-neohellenic                     font-seymour-one
# font-gideon-roman                        font-sf-arabic
# font-gidole                              font-sf-armenian
# font-gidugu                              font-sf-compact
# font-gilbert                             font-sf-georgian
# font-gilda-display                       font-sf-hebrew
# ...
# font-m-plus-1                            sketch@beta
# font-m-plus-1-code                       skype@preview
# font-m-plus-1p                           slack@beta
# font-m-plus-2                            slicer@preview
# font-m-plus-code-latin                   smcfancontrol@beta
# font-ma-shan-zheng                       sonarr@beta
# font-macondo                             sonos-s1-controller
# font-macondo-swash-caps                  sourcetree@beta
# font-mada                                starnet2
# font-madimi-one                          sublime-merge@dev
# font-magra                               sublime-text@dev
# font-maiden-orange                       surge@4
# font-maitree                             svp
# font-major-mono-display                  telegram-desktop@beta
# font-makinas4                            temurin@11
# font-mako                                temurin@17
# font-mali                                temurin@19
# font-mallanna                            temurin@20
# font-mamelon                             temurin@21
# font-mandali                             temurin@8
# font-manjari                             termius@beta
# font-manrope                             threema@beta
# font-mansalva                            thunderbird@beta
# font-manuale                             thunderbird@daily
# font-maple                               toneprint
# font-marcellus                           topaz-photo-ai
# font-marcellus-sc                        tor-browser@alpha
# font-marck-script                        transmission@nightly
# font-margarine                           tsh@13
# font-marhey                              tunnelblick@beta
# font-markazi-text                        typora@dev
# font-marko-one                           ugg
# font-marmelad                            utm@beta
# font-martel                              viable
# font-martel-sans                         virtualbox@6
# font-martian-mono                        virtualbox@beta
# font-martian-mono-nerd-font              virtualbuddy@beta
# font-marvel                              virtualdj
# font-masinahikan                         visual-studio-code@insiders
# font-masinahikan-dene                    vivaldi@snapshot
# font-mate                                vlc@nightly
# font-mate-sc                             vscodium@insiders
# font-material-design-icons-webfont       warcraft-logs-uploader
# font-material-icons                      weasis
# font-material-symbols                    wezterm@nightly
# font-maven-pro                           whatsapp@beta
# font-maven-pro-vf-beta                   whatsapp@legacy
# font-mclaren                             whoozle-android-file-transfer@nightly
# font-mea-culpa                           wine@devel
# font-meddon                              wine@staging
# font-medievalsharp                       wins
# font-medula-one                          wljs-notebook
# font-meera-inimai                        wordpresscom-studio
# font-megrim                              xampp@7
# font-meie-script                         xmind@beta
# font-meltho                              yandex-music
# font-mengshen-regular                    yass
# font-menlo-for-powerline                 zed@preview
# font-meow-script                         zotero@beta
# font-merge-one                           zulu@11
# font-merienda                            zulu@17
# font-merriweather                        zulu@21
# font-merriweather-sans                   zulu@8
# font-mervale-script
#
# You have 110 outdated formulae and 1 outdated cask installed.
#
#
# The 4.3.0 release notes are available on the Homebrew Blog:
#   https://brew.sh/blog/4.3.0
# The 4.3.2 changelog can be found at:
#   https://github.com/Homebrew/brew/releases/tag/4.3.2
# ==> Downloading https://ghcr.io/v2/homebrew/core/dos2unix/manifests/7.5.2
# ######################################################################### 100.0%
# ==> Fetching dos2unix
# ==> Downloading https://ghcr.io/v2/homebrew/core/dos2unix/blobs/sha256:34b49544a
# ######################################################################### 100.0%
# ==> Pouring dos2unix--7.5.2.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/dos2unix/7.5.2: 25 files, 466KB
# ==> Running `brew cleanup dos2unix`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> `brew cleanup` has not been run in the last 30 days, running now...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Removing: /Users/idilunlu/Library/Caches/Homebrew/abseil_bottle_manifest--20230802.1... (77.2KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/aom_bottle_manifest--3.8.0... (19.7KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/assimp_bottle_manifest--5.3.1... (7.5KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/assimp--5.3.1... (3.2MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/boost_bottle_manifest--1.83.0-1... (28.6KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/brotli_bottle_manifest--1.1.0-1... (10KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/brotli--1.1.0... (374.3KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/ca-certificates_bottle_manifest--2023-12-12... (1.8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/cairo_bottle_manifest--1.18.0... (20.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/cairo--1.18.0... (738KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/ceres-solver_bottle_manifest--2.2.0_1... (20.3KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/ceres-solver--2.2.0_1... (3.4MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/cjson_bottle_manifest--1.7.17... (8.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/cjson--1.7.17... (56.1KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/cmake_bottle_manifest--3.28.1... (12.3KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/cmatrix_bottle_manifest--2.0... (10.8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/cmatrix--2.0... (21.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/dav1d_bottle_manifest--1.3.0... (7.4KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/dbus_bottle_manifest--1.14.10... (12.5KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/dbus--1.14.10... (758.3KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/ffmpeg_bottle_manifest--6.0_2... (86.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/freetype_bottle_manifest--2.13.2-1... (10.4KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/freetype--2.13.2... (927.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/frei0r_bottle_manifest--2.3.2... (7.5KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/frei0r--2.3.2... (633.4KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/gcc_bottle_manifest--13.2.0-2... (14.7KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/gcc--13.2.0... (118MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/gettext_bottle_manifest--0.22.4... (10KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/glib_bottle_manifest--2.78.3... (14.7KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/gmp_bottle_manifest--6.3.0... (7.6KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/gmp--6.3.0... (1014.4KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/gnutls_bottle_manifest--3.8.2... (17.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/harfbuzz_bottle_manifest--8.3.0... (24KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/hdf5_bottle_manifest--1.14.3... (14.6KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/highway_bottle_manifest--1.0.7... (9.7KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/hwloc_bottle_manifest--2.10.0... (8.2KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/hwloc--2.10.0... (4.2MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/jasper_bottle_manifest--4.1.1... (8.2KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/jpeg-xl_bottle_manifest--0.8.2_1-1... (18.5KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/krb5_bottle_manifest--1.21.2... (14.3KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/krb5--1.21.2... (1.3MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/leptonica_bottle_manifest--1.84.0... (15.8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libaec_bottle_manifest--1.1.2... (7.3KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libarchive_bottle_manifest--3.7.2... (12.1KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libmicrohttpd_bottle_manifest--0.9.77... (18.6KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libnghttp2_bottle_manifest--1.58.0... (7.4KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/librist_bottle_manifest--0.2.10... (21.0KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/librsvg_bottle_manifest--2.57.1... (32.5KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libsodium_bottle_manifest--1.0.19... (7.5KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libsodium--1.0.19... (374.8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libtiff_bottle_manifest--4.6.0... (12.1KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libtiff--4.6.0... (1.5MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libvpx_bottle_manifest--1.13.1... (7.4KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libvpx--1.13.1... (1.7MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libx11_bottle_manifest--1.8.7... (13.8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libxcb_bottle_manifest--1.16-1... (15.8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libzip_bottle_manifest--1.10.1-1... (11.6KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/libzip--1.10.1... (135.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/llvm_bottle_manifest--17.0.6... (19.7KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/luajit--2.1.1710088188... (874.8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/mbedtls_bottle_manifest--3.5.1... (7.2KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/mpfr_bottle_manifest--4.2.1... (8.0KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/mpfr--4.2.1... (1021.3KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/mpg123_bottle_manifest--1.32.3... (7.8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/numpy_bottle_manifest--1.26.2-2... (17.8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/openblas_bottle_manifest--0.3.25... (14.2KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/opencv_bottle_manifest--4.8.1_5... (125.6KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/opencv@4.7.0--contrib--4.7.0.tar.gz... (56.7MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/openexr_bottle_manifest--3.2.1... (8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/openjdk@11_bottle_manifest--11.0.21... (23.8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/openssl@1.1_bottle_manifest--1.1.1w... (10.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/openssl@3_bottle_manifest--3.2.0_1... (9.2KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/openvino_bottle_manifest--2023.2.0... (18.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/p11-kit_bottle_manifest--0.25.3... (9.6KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/p11-kit--0.25.3... (868.4KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/postgresql@14_bottle_manifest--14.10_1... (19.3KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/protobuf_bottle_manifest--25.1-1... (9.7KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/pugixml_bottle_manifest--1.14... (7.4KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/pugixml--1.14... (140.6KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/pyenv_bottle_manifest--2.3.35... (26KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/pyqt_bottle_manifest--6.6.1... (63.1KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/pyqt--6.6.1... (6.4MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/python@3.10_bottle_manifest--3.10.13_1... (21.7KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/python@3.11_bottle_manifest--3.11.6_1... (21.8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/python@3.12_bottle_manifest--3.12.1... (23.2KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/python@3.9_bottle_manifest--3.9.18_1... (21.0KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/qt_bottle_manifest--6.6.1... (71.6KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/readline_bottle_manifest--8.2.7... (7.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/readline--8.2.7... (574.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/sdl2_bottle_manifest--2.28.5-1... (13.8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/sqlite_bottle_manifest--3.44.2... (8.4KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/srt_bottle_manifest--1.5.3... (10.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/srt--1.5.3... (1.6MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/suite-sparse_bottle_manifest--7.3.1... (19.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/svt-av1_bottle_manifest--1.8.0-1... (7.7KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/tbb_bottle_manifest--2021.11.0-1... (9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/tbb--2021.11.0... (721.4KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/tesseract_bottle_manifest--5.3.3... (26.5KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/tldr_bottle_manifest--1.6.1... (12.5KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/tldr--1.6.1... (16.3KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/tmux_bottle_manifest--3.3a_3... (10.1KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/tree-sitter--0.22.2... (4.9MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/typst--0.11.0... (13.5MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/unbound_bottle_manifest--1.19.0... (12.2KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/utf8cpp_bottle_manifest--4.0.4... (1.8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/utf8proc_bottle_manifest--2.9.0... (7.5KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/utf8proc--2.9.0... (176.9KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/vtk_bottle_manifest--9.2.6_5-1... (54KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/webp_bottle_manifest--1.3.2... (15.3KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/webp--1.3.2... (793.2KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/x264_bottle_manifest--r3108... (7.4KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/x264--r3108... (1.9MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/xz_bottle_manifest--5.4.5... (7.5KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/zeromq_bottle_manifest--4.3.5_1... (8KB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/zeromq--4.3.5_1... (1.6MB)
# Removing: /Users/idilunlu/Library/Caches/Homebrew/zlib_bottle_manifest--1.3... (9.2KB)
# ==> Autoremoving 1 unneeded formula:
# openssl@1.1
# Uninstalling /opt/homebrew/Cellar/openssl@1.1/1.1.1u... (8,101 files, 18MB)
#
# Warning: The following openssl@1.1 configuration files have not been removed!
# If desired, remove them manually with `rm -rf`:
#   /opt/homebrew/etc/openssl@1.1
#   /opt/homebrew/etc/openssl@1.1/cert.pem
#   /opt/homebrew/etc/openssl@1.1/ct_log_list.cnf
#   /opt/homebrew/etc/openssl@1.1/ct_log_list.cnf.dist
#   /opt/homebrew/etc/openssl@1.1/misc
#   /opt/homebrew/etc/openssl@1.1/misc/CA.pl
#   /opt/homebrew/etc/openssl@1.1/misc/tsget
#   /opt/homebrew/etc/openssl@1.1/misc/tsget.default
#   /opt/homebrew/etc/openssl@1.1/misc/tsget.pl
#   /opt/homebrew/etc/openssl@1.1/misc/tsget.pl.default
#   /opt/homebrew/etc/openssl@1.1/openssl.cnf
#   /opt/homebrew/etc/openssl@1.1/openssl.cnf.dist
#
# Warning: The following may be openssl@1.1 configuration files and have not been removed!
# If desired, remove them manually with `rm -rf`:
#   /opt/homebrew/etc/openssl@3
# Removing: /Users/idilunlu/Library/Caches/Homebrew/portable-ruby-3.1.4.arm64_big_sur.bottle.tar.gz... (12.4MB)
# dos2unix: converting file sr_sr3_64_512.json to Unix format...
# patching file sr_sr3_64_512.json

# %% [markdown]
# ### Prepair Data
# Upload 64x64 pixel image(s) to be upscaled
#
# *Click the **browse** button and select the images you would like to upscale.*

# %%
# %cd /Users/idilunlu/Desktop/sr3_trial/Image-Super-Resolution-via-Iterative-Refinement/
# !mkdir -p input
# %cd /Users/idilunlu/Desktop/sr3_trial/Image-Super-Resolution-via-Iterative-Refinement/input/
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  savefile = open(fn, 'wb')
  savefile.write(uploaded[fn])
  print('Successfully uploaded "{}" ({} bytes).'.format(fn, len(uploaded[fn])))
  savefile.close()
# Out:
# /Users/idilunlu/Desktop/sr3_trial/Image-Super-Resolution-via-Iterative-Refinement
# /Users/idilunlu/Desktop/sr3_trial/Image-Super-Resolution-via-Iterative-Refinement/input
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       2 get_ipython().system('mkdir -p input')
#       3 get_ipython().run_line_magic('cd', '/Users/idilunlu/Desktop/sr3_trial/Image-Super-Resolution-via-Iterative-Refinement/input/')
# ----> 4 from google.colab import files
#       6 uploaded = files.upload()
#       8 for fn in uploaded.keys():
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# Generate neccesary files and directory structure to begin upscaling.

# %%
# %cd /content/Image-Super-Resolution-via-Iterative-Refinement/
# !python data/prepare_data.py --path /content/Image-Super-Resolution-via-Iterative-Refinement/input/ --size 64,512 --out ./dataset/celebahq

# %% [markdown]
# ## Upscaling
# ---
# Note that this may take ~30 minutes or more, depending on which GPU you get.
#
# Output images will be located under ./experiments/\<some folder\>/results

# %%
# !python infer.py -c /content/Image-Super-Resolution-via-Iterative-Refinement/config/sr_sr3_64_512.json
